# %%
import pandas as pd

#load the dataset into dataframe
df = pd.read_csv("C:\\Users\\punit\\OneDrive\\Desktop\\kaggle dataset\\train.csv.csv")

#show the first 5 rows
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#show summary about dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
#summary of non numerical data
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
#check column data type
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
#check column names
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
#check for missing values
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
#check for duplicate rows
df.duplicated().sum()
# Out:
# 0

# %%
#show descriptive statistics


df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
#remove all rows that contain atleast one missing value
df_cleaned = df.dropna()

# %%
#check if there are any missing values still left

df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
#LotFrontage has 259 missing values. Since lot sizes have outliers, using a median rather than mean is a better option.
df["LotFrontage"].fillna(df["LotFrontage"].median(), inplace=True)
# Out:
# C:\Users\punit\AppData\Local\Temp\ipykernel_27676\2655502448.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["LotFrontage"].fillna(df["LotFrontage"].median(), inplace=True)

# %%
#check for missing values again
df.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
#now that we dont have any missing values, lets visualize the data 

import matplotlib.pyplot as plt
import seaborn as sns

#we are creating a histogram that shows how values of LotFrontage are distributed 

plt.figure(figsize=(10, 5))
sns.histplot(df["LotFrontage"], bins=30, kde=True, color="blue")
plt.title("Distribution of LotFrontage")
plt.xlabel("Lot Frontage")
plt.ylabel("Count")
plt.show()

#the kernel density curve

# %%
#boxplots are the ideal graph type to spot outliers

plt.figure(figsize=(8, 5))
sns.boxplot(x=df["LotFrontage"], color="blue")
plt.title("Boxplot of LotFrontage")
plt.show()

# %%
#we are using a scatterplot to show the relationship between LotFrontage and SalePrice

plt.figure(figsize=(10, 6))
sns.scatterplot(x=df["LotFrontage"], y=df["SalePrice"], color="red")
plt.title("LotFrontage vs SalePrice")
plt.xlabel("Lot Frontage")
plt.ylabel("Sale Price")
plt.show()

# %%
#we are trying to find how many properties are in each neighborhood

plt.figure(figsize=(12, 5))
sns.countplot(y=df["Neighborhood"], order=df["Neighborhood"].value_counts().index, palette="viridis")
plt.title("Distribution of Properties by Neighborhood")
plt.show()
# Out:
# C:\Users\punit\AppData\Local\Temp\ipykernel_27676\4250074054.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df["Neighborhood"], order=df["Neighborhood"].value_counts().index, palette="viridis")

# %%
#here we try to explore if sale price and lot area are correlated
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.scatterplot(x=df["LotArea"], y=df["SalePrice"], color="green", alpha=0.5)
plt.title("Sale Price vs. Lot Area")
plt.xlabel("Lot Area")
plt.ylabel("Sale Price")
plt.show()

# %%
#here we try to explore the relationship between year built and sale price
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.scatterplot(x=df["YearBuilt"], y=df["SalePrice"], color="blue", alpha=0.5)
plt.title("Sale Price vs. Year Built")
plt.xlabel("Year Built")
plt.ylabel("Sale Price")
plt.show()

# %%
#group year built into nearest decade
df["DecadeBuilt"] = (df["YearBuilt"] // 10) * 10 

#plot graph of sale prices in each decade

plt.figure(figsize=(12, 6))
sns.boxplot(x=df["DecadeBuilt"], y=df["SalePrice"], palette="viridis")
plt.xticks(rotation=45)
plt.title("Sale Price by Decade Built")
plt.xlabel("Decade Built")
plt.ylabel("Sale Price")
plt.show()
# Out:
# C:\Users\punit\AppData\Local\Temp\ipykernel_27676\888456972.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df["DecadeBuilt"], y=df["SalePrice"], palette="viridis")

# %%
#we are creating a historgram showing the average sale price of homes in each neighborhood

avg_price_by_neighborhood = df.groupby("Neighborhood")["SalePrice"].mean().sort_values()

plt.figure(figsize=(14, 6))
sns.barplot(x=avg_price_by_neighborhood.index, y=avg_price_by_neighborhood.values, palette="coolwarm")
plt.xticks(rotation=90)
plt.title("Average Sale Price by Neighborhood")
plt.xlabel("Neighborhood")
plt.ylabel("Average Sale Price")
plt.show()
# Out:
# C:\Users\punit\AppData\Local\Temp\ipykernel_27676\2943021117.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_price_by_neighborhood.index, y=avg_price_by_neighborhood.values, palette="coolwarm")

# %%
#we are visualizing the relationship between the neighborhood and lot area.
#this will help provide insight on whether certain neighborhoods have bigger lot area sizes and hence this sale price.

avg_lotarea_by_neighborhood = df.groupby("Neighborhood")["LotArea"].mean().sort_values()

plt.figure(figsize=(14, 6))
sns.barplot(x=avg_lotarea_by_neighborhood.index, y=avg_lotarea_by_neighborhood.values, palette="coolwarm")
plt.xticks(rotation=90)
plt.title("Average Lot Area by Neighborhood")
plt.xlabel("Neighborhood")
plt.ylabel("Average Lot Area (sq ft)")
plt.show()
# Out:
# C:\Users\punit\AppData\Local\Temp\ipykernel_27676\3150271148.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_lotarea_by_neighborhood.index, y=avg_lotarea_by_neighborhood.values, palette="coolwarm")

# %%
#we are visualizing the relationship between neighborhood and lotfrontage
#this will provide insight on whether certain neighborhoods have larger lot frontages and hence this affects sale price of homes.

avg_lotfrontage_by_neighborhood = df.groupby("Neighborhood")["LotFrontage"].mean().sort_values()

plt.figure(figsize=(14, 6))
sns.barplot(x=avg_lotfrontage_by_neighborhood.index, y=avg_lotfrontage_by_neighborhood.values, palette="coolwarm")
plt.xticks(rotation=90)
plt.title("Average Lot Frontage by Neighborhood")
plt.xlabel("Neighborhood")
plt.ylabel("Average Lot Frontage (feet)")
plt.show()
# Out:
# C:\Users\punit\AppData\Local\Temp\ipykernel_27676\1515418011.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_lotfrontage_by_neighborhood.index, y=avg_lotfrontage_by_neighborhood.values, palette="coolwarm")

# %%
#we check for columns containing bedroom or bathroom

columns_with_bed_bath = [col for col in df.columns if "bed" in col.lower() or "bath" in col.lower()]
print("Columns containing 'bedroom' or 'bathroom':", columns_with_bed_bath)
# Out:
# Columns containing 'bedroom' or 'bathroom': ['BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr']

# %%
#we explore the relationship between number of full bathrooms a house has and its sale price

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.scatterplot(x=df["FullBath"], y=df["SalePrice"], alpha=0.6)

plt.xlabel("Number of Full Bathrooms")
plt.ylabel("Sale Price")
plt.title("Full Bathrooms vs Sale Price")
plt.show()

# %%
#we explore the relationship between full bathrooms in the basement and sale price

plt.figure(figsize=(8, 5))
sns.scatterplot(x=df["BsmtFullBath"], y=df["SalePrice"], alpha=0.6)

plt.xlabel("Number of Basement Full Bathrooms")
plt.ylabel("Sale Price")
plt.title("BsmtFullBath vs Sale Price")
plt.show()

# %%
#we explore the relationship between bedrooms above ground and sale price

plt.figure(figsize=(8, 5))
sns.scatterplot(x=df["BedroomAbvGr"], y=df["SalePrice"], alpha=0.6)

plt.xlabel("Number of Bedrooms Above Ground")
plt.ylabel("Sale Price")
plt.title("BedroomAbvGr vs Sale Price")
plt.show()

# %%
#we calculate the correlation coefficient between sale price and number of bedrooms above ground
correlation = df["BedroomAbvGr"].corr(df["SalePrice"])
print(f"Correlation between BedroomAbvGr and SalePrice: {correlation:.4f}")
# Out:
# Correlation between BedroomAbvGr and SalePrice: 0.1682

# %%
#we plot the relationship between half bathrooms and sale price

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.scatterplot(x=df["HalfBath"], y=df["SalePrice"], alpha=0.6)

plt.xlabel("Number of Half Bathrooms")
plt.ylabel("Sale Price")
plt.title("HalfBath vs Sale Price")
plt.show()

# %%
#Plot the relationship between basement half bathrooms and sale price
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.scatterplot(x=df["BsmtHalfBath"], y=df["SalePrice"], alpha=0.6)

plt.xlabel("Number of Basement Half Bathrooms")
plt.ylabel("Sale Price")
plt.title("BsmtHalfBath vs Sale Price")
plt.show()

# %%
#Calculate the average sale price of homes 
average_price = df["SalePrice"].mean()
print(f"Average Sale Price of Homes: ${average_price:,.2f}")

#average sale price of house by neighborhood
avg_price_by_neighborhood = df.groupby("Neighborhood")["SalePrice"].mean().sort_values(ascending=False)
print(avg_price_by_neighborhood)

#find 10 most expensive houses in the dataset and their sale prices and neighborhoods
import matplotlib.pyplot as plt
import seaborn as sns

# Select the 10 most expensive houses
top_expensive_houses = df[["Neighborhood", "SalePrice"]].nlargest(10, "SalePrice")

# Set figure size
plt.figure(figsize=(10, 6))

# Create bar plot
ax = sns.barplot(x=top_expensive_houses["SalePrice"], 
                 y=top_expensive_houses["Neighborhood"], 
                 palette="viridis")

# Add value labels on each bar
for index, value in enumerate(top_expensive_houses["SalePrice"]):
    plt.text(value, index, f"${value:,.0f}", va="center", fontsize=10, color="black")

# Titles and labels
plt.xlabel("Sale Price ($)", fontsize=12)
plt.ylabel("Neighborhood", fontsize=12)
plt.title("Top 10 Most Expensive Houses by Neighborhood", fontsize=14)
plt.xticks(rotation=30)

# Show plot
plt.show()
# Out:
# Average Sale Price of Homes: $180,921.20
# Neighborhood
# NoRidge    335295.317073
# NridgHt    316270.623377
# StoneBr    310499.000000
# Timber     242247.447368
# Veenker    238772.727273
# Somerst    225379.837209
# ClearCr    212565.428571
# Crawfor    210624.725490
# CollgCr    197965.773333
# Blmngtn    194870.882353
# Gilbert    192854.506329
# NWAmes     189050.068493
# SawyerW    186555.796610
# Mitchel    156270.122449
# NAmes      145847.080000
# NPkVill    142694.444444
# SWISU      142591.360000
# Blueste    137500.000000
# Sawyer     136793.135135
# OldTown    128225.300885
# Edwards    128219.700000
# BrkSide    124834.051724
# BrDale     104493.750000
# IDOTRR     100123.783784
# MeadowV     98576.470588
# Name: SalePrice, dtype: float64
# C:\Users\punit\AppData\Local\Temp\ipykernel_27676\2890133983.py:20: FutureWarning:
#
# ...
